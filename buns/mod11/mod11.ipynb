# %% [markdown]
# # Numpy
# ### Если задания покажутся сложными, рекомендую пройти краткий курс по основам numpy [ссылка1](https://stepik.org/lesson/241329/step/1?unit=213910), [ссылка2](https://stepik.org/lesson/16462/step/1?unit=4283)

# %%
import numpy as np
import random
import scipy.stats as sps
import cv2

# %% [markdown]
# ### Задание 1
# В первой задаче вам предлагается перемножить две квадратные матрицы двумя способами -- без использования пакета ***numpy*** и с ним.

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j),
# здесь i -- число строк, j -- число столбцов.
a = np.random.sample((100, 100))
b = np.random.sample((100, 100))
# выведите размерность (ранг) каждой матрицы с помощью функции ndim.
# Используйте функцию shape, что она вывела?
# ========
print("ранг a =",a.ndim, "\nранг b =", b.ndim)
print("размер матрицы a =",a.shape,"\nразмер матрицы b =",b.shape)
# ========
print(a)
print(b)
# Out:
# ранг a = 2
# ранг b = 2
# размер матрицы a = (100, 100)
# размер матрицы b = (100, 100)
# [[0.8742592  0.05270455 0.40905098 ... 0.74311288 0.65110761 0.70330597]
#  [0.14766004 0.64828009 0.42619984 ... 0.21449743 0.56214309 0.02577619]
#  [0.99632223 0.17496656 0.08158436 ... 0.23762313 0.39579792 0.33113189]
#  ...
#  [0.62878424 0.12240248 0.83604276 ... 0.11946588 0.67589735 0.11675729]
#  [0.35837478 0.20948065 0.29549644 ... 0.36366465 0.53117056 0.57764498]
#  [0.30744374 0.51993064 0.24093847 ... 0.84066236 0.40238415 0.12513491]]
# [[0.75227809 0.7653606  0.84865064 ... 0.36627698 0.10677172 0.85647301]
#  [0.13549577 0.7292739  0.54127861 ... 0.35900134 0.62128362 0.22764631]
#  [0.08388799 0.28440387 0.62884327 ... 0.28710601 0.4886983  0.60108943]
#  ...
#  [0.78996387 0.22783649 0.83802615 ... 0.17464725 0.77605586 0.24598171]
#  [0.25191001 0.05330083 0.48894606 ... 0.98177913 0.68710653 0.79708512]
#  [0.23988839 0.2303723  0.62405435 ... 0.99667948 0.40369049 0.54007059]]

# %% [markdown]
# Без использования numpy

# %%
def mult(a, b):
    if len(a[0]) != len(b):
        raise ValueError("Количество столбцов матрицы a должно быть равно количеству строк матрицы b")

    result = []
    for i in range(len(a)):
        row = []
        for j in range(len(b[0])):
            sum = 0
            for k in range(len(b)):
                sum += a[i][k] * b[k][j]
            row.append(sum)
        result.append(row)

    return result

# %% [markdown]
# C использованием numpy

# %%
import numpy as np

def np_mult(a, b):
    return np.dot(a, b)

# %%
# %%time
# засечем время работы функции без NumPy
M1 = mult(a, b)
# Out:
# CPU times: user 652 ms, sys: 0 ns, total: 652 ms
# Wall time: 661 ms

# %%
# %%time
# засечем время работы функции с NumPy
M2 = np_mult(a, b)
# Out:
# CPU times: user 1.54 ms, sys: 0 ns, total: 1.54 ms
# Wall time: 15 ms

# %%
# проверим корректность
np.abs(np.array(M1) - M2).sum()
# Out:
# 1.5134560271690134e-11

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вам подаются на вход два вектора `a` и `b` в трехмерном пространстве. Заполните их случайными числами. Реализуйте их скалярное произведение с помощью  `NumPy` и без. Засеките время работы, как это показано в заданиях выше.

# %%
a = np.random.sample((1, 3))
a = list(a)[0]
b = np.random.sample((1, 3))
b = list(b)[0]
print(a, b)
# Out:
# [0.42118268 0.09505737 0.66698012] [0.94696938 0.710772   0.45827392]

# %%
def scalar_product(a, b):
    s = 0
    for i in range(len(a)):
        s += a[i] * b[i]
    return s

# %%
def np_scalar_product(a, b):
    return np.dot(a, b)

# %%
# %time product_1 = scalar_product(a,b)
# %time product_2 = np_scalar_product(a,b)
# проверим корректность:
np.abs(product_1 - product_2).sum()
# Out:
# CPU times: user 28 µs, sys: 0 ns, total: 28 µs
# Wall time: 31.7 µs
# CPU times: user 93 µs, sys: 0 ns, total: 93 µs
# Wall time: 97.5 µs
# 0.0

# %% [markdown]
# Почему методы ***numpy*** оказываются эффективнее? Что вы можете сказать о скорости вычислений в NumPy?

# %% [markdown]
# **Ответ:** numpy написан на более быстром(чем сам python) C и Fortran, так же он использует более оптимизированные и эффективные реализации алгоритмов линейной алгебры, что повышает скорость вычислений.

# %% [markdown]
# ------------------

# %% [markdown]
# ### Задание 3
# Напишите функцию, которая находим сумму четных диагональныех элементов квадратной матрицы. Если таких элементов нет, то вывести `0`.

# %%
# функция, решающая задачу с помощью NumPy
def np_diag_2k(a):
    diag = np.diag(a)  # Получаем диагональ матрицы
    even_diag = diag[diag % 2 == 0]  # Выбираем четные элементы
    res = np.sum(even_diag) if len(even_diag) > 0 else 0  # Считаем их сумму или возвращаем 0, если таких нет
    return res

# %%
# зададим некоторую квадратную матрицу
a = np.random.randint(1, 10, size=(5, 5))
a
# Out:
# array([[5, 7, 1, 5, 6],
#        [2, 9, 9, 4, 8],
#        [4, 4, 3, 7, 3],
#        [2, 2, 2, 3, 7],
#        [6, 1, 7, 8, 6]])

# %%
# %%time
# засечем время работы функции с NumPy
np_diag_2k(a)
# Out:
# CPU times: user 336 µs, sys: 0 ns, total: 336 µs
# Wall time: 343 µs
# 6

# %% [markdown]
# ### Задание 4
# На вход дан двумерный массив $X$. Напишите функцию, которая для каждой строчки $x = (x_1, x_2, \ldots, x_n)$ массива $X$  строит строчку $s = (s_1, s_2, \ldots, s_n)$, где $s_k=\frac{x_1+...+x_k}{k}$, а затем выдаёт массив из построенных строчек. Используйте библиотеку numpy (вам поможет функция cumsum). Выходом функции должен быть двумерный массив той же формы, что и $X$.

# %%
# функция, решающая задачу с помощью NumPy
import numpy as np
import scipy.stats as sps

def np_sec_av(*args):
    cumsum_args = np.cumsum(np.array(args), axis=1)
    indices = np.arange(1, cumsum_args.shape[1] + 1)
    result = cumsum_args / indices[:, np.newaxis]
    return result

# %%
# зададим некоторую последовательность и проверим ее на ваших функциях.
# функция должна работать ~ в 50 раз быстрее, чем без Numpy
A = sps.uniform.rvs(size=10**3)
#  0.58481328 0.53476303 0.04126485 0.26013988 0.30310606 0.69934349
#  0.36988286 0.37621609 0.82940324 0.07024014 0.30217406 0.64227815
#  0.55386976 0.87323306 0.64924887 0.13814158 0.66269905 0.46812073
#  0.1693383  0.09545454 0.15128725 0.57080174 0.57002196 0.6570623
#  0.868194   0.23716509 0.2266984  0.29795731 0.4542821  0.01947474
#  0.8725587  0.92737736 0.25314872 0.32858728 0.84492929 0.14038464
#  0.57380388 0.82058696 0.94735045 0.51878309 0.66417793 0.2727721
#  0.51763528 0.4221979  0.17068064 0.58952739 0.63696997 0.68195939
#  0.99953054 0.0794144  0.00945221 0.61547883]
# CPU times: user 215 µs, sys: 7.74 ms, total: 7.95 ms
# Wall time: 8.28 ms

# %% [markdown]
# ### Задание 5
# Написать функцию для кодирование массива (Run-length encoding). Все подряд повторения элементов функция сжимает в один элемент и считает количество повторений. Функция возвращает кортеж из двух векторов одинаковой длины. Первый содержит элементы, а второй — сколько раз их нужно повторить.
#
# Пример: encode(np.array([1, 2, 2, 3, 3, 1, 1, 5, 5, 2, 3, 3])) = (np.array[1, 2, 3, 1, 5, 2, 3]), np.array[1, 2, 2, 2, 2, 1, 2])

# %%
# функция, решающая задачу с помощью NumPy
import numpy as np

def np_encode(a):
    # Используем функцию np.diff для нахождения изменений в массиве
    changes = np.where(np.diff(a) != 0)[0]

    # Если массив пустой, то каждый элемент повторяется один раз
    if len(changes) == 0:
        return a, np.array([len(a)])

    # Создаем новый массив для элементов и их количества повторений
    elements = np.append(a[changes], a[-1])  # Элементы
    counts = np.diff(np.append(-1, changes))  # Количество повторений

    return elements, counts

# %%
from itertools import groupby
X = np.array([1, 2, 2, 3, 3, 1, 1, 5, 5, 2, 3, 3])
# %time x, num = np_encode(X)
# Out:
# CPU times: user 301 µs, sys: 26 µs, total: 327 µs
# Wall time: 312 µs

# %% [markdown]
# ### Задание 6
#
# Пусть задан некоторый одномерный массив $X$. Надо построить новый массив, где все элементы с нечетными индексами требуется заменить на число $a$ (если оно не указано, то на 1). Все элементы с четными индексами нужно возвести в куб. Затем записать элементы в обратном порядке относительно их позиций. Массив $X$ при этом должен остаться *без изменений*. В конце требуется слить массив X с преобразованным X и вывести в обратном порядке.
#
# Пример:
# X = [100, 200, 300, 400, 500] -> [100, a, 300, a, 500] -> [500^3, a, 300^3, a, 100^3] -> склеиваем -> [100, 200, 300, 400, 500, 500^3, a, 300^3, a, 100^3]

# %%
# функция, решающая задачу с помощью NumPy
import numpy as np

def np_transformation(X, a=1):
    modified = np.copy(X)
    modified[::2] = modified[::2] ** 3
    modified[1::2] = a

    reversed_modified = np.flip(modified)

    result = np.concatenate((X, reversed_modified))
    return result

# %%
X = np.array([i for i in range(1, 10, 2)])
# функция должна работать ~ в 20 раз быстрее, чем без Numpy
# %time S2 = np_transformation(X, 5)
# Out:
# CPU times: user 1.22 ms, sys: 13 µs, total: 1.23 ms
# Wall time: 3.71 ms
